# %% [markdown]
# ---
# title: "Introduction"
# format:
#   html:
#     code-fold: true
# jupyter: python3
# ---

# %% [markdown]
# # Intro

# %% [markdown]
# Requirements to full covergae of this topic in depth
#
# - **Math**
#     - Calculus
#     - Linear Algebra
#     - Optimizatoin
#     - Probablity and Statistics
#     - Discrete Mathematics
#     - Algorithms
#     - Graph theory
#     - GameTheory
# - **AI**
#     - [Machine Learning](https://github.com/aliakbar1881/AI/tree/main/ML)
#     - [Deep Learning](https://github.com/aliakbar1881/AI/tree/main/DL)
#     - [ReinforcemetnLearning](https://github.com/aliakbar1881/AI/tree/main/RL)
#     - [LLM](https://github.com/aliakbar1881/AI/tree/main/LLM)
#     - VLM
